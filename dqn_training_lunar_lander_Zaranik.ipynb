# %%
# !pip install swig
# !pip install gymnasium[box2d]
# !pip install box2d
# Out:
# Collecting swig
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 73.1 MB/s eta 0:00:00
# Installing collected packages: swig
# Successfully installed swig-4.4.0
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 26.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2398999 sha256=c793eb2ab26f7c080bed7dd574c7fc13d6a9b32dd0c7c86ecf989ba81b7b865f
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.5
# Collecting box2d
#   Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (573 bytes)
# Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 100.1 MB/s eta 0:00:00
# Installing collected packages: box2d
# Successfully installed box2d-2.3.10

# %%
import gymnasium as gym
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from collections import deque

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
# ---- Сеть DQN ----
class DQN(nn.Module):
  def __init__(self, obs_dim, act_dim):
    super().__init__()
    self.model = nn.Sequential(
      nn.Linear(obs_dim, 128),
      nn.ReLU(),
      nn.Linear(128, 128),
      nn.ReLU(),
      nn.Linear(128, act_dim)
    )

  def forward(self, x):
    return self.model(x)


# ---- Replay Buffer ----
class ReplayBuffer:
  def __init__(self, capacity=100000):
    self.buffer = deque(maxlen=capacity)

  def push(self, s, a, r, sn, done):
    self.buffer.append((s, a, r, sn, done))

  def sample(self, batch_size):
    batch = random.sample(self.buffer, batch_size)
    s, a, r, sn, d = zip(*batch)
    return np.array(s), a, r, np.array(sn), d

  def __len__(self):
    return len(self.buffer)


# ---- DQN обучение ----
def train_dqn(episodes=600):
  env = gym.make("LunarLander-v3")
  obs_dim = env.observation_space.shape[0]
  act_dim = env.action_space.n

  qnet = DQN(obs_dim, act_dim).to(device)
  qtarget = DQN(obs_dim, act_dim).to(device)
  qtarget.load_state_dict(qnet.state_dict())

  optimizer = optim.Adam(qnet.parameters(), lr=1e-3)
  buffer = ReplayBuffer()

  gamma = 0.99
  batch_size = 64
  epsilon = 1.0
  eps_min = 0.05
  eps_decay = 0.995

  rewards_history = []

  for ep in range(episodes):
    state, _ = env.reset()
    total_reward = 0

    for _ in range(1000):
      # epsilon-greedy
      if random.random() < epsilon:
        action = env.action_space.sample()
      else:
        st = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
        action = torch.argmax(qnet(st)).item()

      next_state, reward, terminated, truncated, _ = env.step(action)
      done = terminated or truncated
      total_reward += reward

      buffer.push(state, action, reward, next_state, done)
      state = next_state

      if len(buffer) > batch_size:
        s, a, r, sn, d = buffer.sample(batch_size)


        s = torch.tensor(s, dtype=torch.float32).to(device)
        sn = torch.tensor(sn, dtype=torch.float32).to(device)
        a = torch.tensor(a).long().to(device)
        r = torch.tensor(r, dtype=torch.float32).to(device)
        d = torch.tensor(d, dtype=torch.float32).to(device)

        # Q(s,a)
        qvals = qnet(s).gather(1, a.unsqueeze(1)).squeeze(1)

        # TD target
        next_q = qtarget(sn).max(1)[0]
        target = r + gamma * next_q * (1 - d)

        loss = nn.MSELoss()(qvals, target.detach())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

      if done:
        break

    rewards_history.append(total_reward)
    epsilon = max(eps_min, epsilon * eps_decay)

    # soft update target network
    if ep % 10 == 0:
      qtarget.load_state_dict(qnet.state_dict())

    print(f"Episode {ep} | Reward: {total_reward:.1f} | Epsilon: {epsilon:.3f}")

  return qnet, rewards_history

# %%
# ---- Запуск обучения ----
qnet, rewards = train_dqn(episodes=500)
# Out:
# Episode 0 | Reward: -348.2 | Epsilon: 0.995
# Episode 1 | Reward: -288.9 | Epsilon: 0.990
# Episode 2 | Reward: -43.9 | Epsilon: 0.985
# Episode 3 | Reward: -273.8 | Epsilon: 0.980
# Episode 4 | Reward: -468.0 | Epsilon: 0.975
# Episode 5 | Reward: -132.5 | Epsilon: 0.970
# Episode 6 | Reward: -198.8 | Epsilon: 0.966
# Episode 7 | Reward: -508.8 | Epsilon: 0.961
# Episode 8 | Reward: -329.2 | Epsilon: 0.956
# Episode 9 | Reward: -80.1 | Epsilon: 0.951
# Episode 10 | Reward: -221.9 | Epsilon: 0.946
# Episode 11 | Reward: -101.0 | Epsilon: 0.942
# Episode 12 | Reward: -92.6 | Epsilon: 0.937
# Episode 13 | Reward: -376.4 | Epsilon: 0.932
# Episode 14 | Reward: -88.7 | Epsilon: 0.928
# Episode 15 | Reward: -54.8 | Epsilon: 0.923
# Episode 16 | Reward: -27.5 | Epsilon: 0.918
# Episode 17 | Reward: -121.5 | Epsilon: 0.914
# Episode 18 | Reward: -182.0 | Epsilon: 0.909
# Episode 19 | Reward: -83.9 | Epsilon: 0.905
# Episode 20 | Reward: -28.6 | Epsilon: 0.900
# Episode 21 | Reward: -99.4 | Epsilon: 0.896
# Episode 22 | Reward: -75.9 | Epsilon: 0.891
# Episode 23 | Reward: 39.8 | Epsilon: 0.887
# Episode 24 | Reward: -181.3 | Epsilon: 0.882
# Episode 25 | Reward: -100.8 | Epsilon: 0.878
# Episode 26 | Reward: -174.5 | Epsilon: 0.873
# Episode 27 | Reward: -216.6 | Epsilon: 0.869
# Episode 28 | Reward: -69.6 | Epsilon: 0.865
# Episode 29 | Reward: -112.5 | Epsilon: 0.860
# Episode 30 | Reward: -75.3 | Epsilon: 0.856
# Episode 31 | Reward: -62.8 | Epsilon: 0.852
# Episode 32 | Reward: -69.0 | Epsilon: 0.848
# Episode 33 | Reward: -70.7 | Epsilon: 0.843
# Episode 34 | Reward: -51.3 | Epsilon: 0.839
# Episode 35 | Reward: -100.3 | Epsilon: 0.835
# Episode 36 | Reward: -126.3 | Epsilon: 0.831
# Episode 37 | Reward: -76.6 | Epsilon: 0.827
# Episode 38 | Reward: -356.1 | Epsilon: 0.822
# Episode 39 | Reward: -176.9 | Epsilon: 0.818
# Episode 40 | Reward: -178.5 | Epsilon: 0.814
# Episode 41 | Reward: -127.6 | Epsilon: 0.810
# Episode 42 | Reward: -160.7 | Epsilon: 0.806
# Episode 43 | Reward: -64.0 | Epsilon: 0.802
# Episode 44 | Reward: -106.0 | Epsilon: 0.798
# Episode 45 | Reward: -102.2 | Epsilon: 0.794
# Episode 46 | Reward: -149.6 | Epsilon: 0.790
# Episode 47 | Reward: -97.5 | Epsilon: 0.786
# Episode 48 | Reward: -216.3 | Epsilon: 0.782
# Episode 49 | Reward: -146.8 | Epsilon: 0.778
# Episode 50 | Reward: -15.9 | Epsilon: 0.774
# Episode 51 | Reward: -179.8 | Epsilon: 0.771
# Episode 52 | Reward: -48.4 | Epsilon: 0.767
# Episode 53 | Reward: -166.0 | Epsilon: 0.763
# Episode 54 | Reward: -125.8 | Epsilon: 0.759
# Episode 55 | Reward: -117.7 | Epsilon: 0.755
# Episode 56 | Reward: -125.1 | Epsilon: 0.751
# Episode 57 | Reward: -82.0 | Epsilon: 0.748
# Episode 58 | Reward: -31.1 | Epsilon: 0.744
# Episode 59 | Reward: -78.1 | Epsilon: 0.740
# Episode 60 | Reward: -331.4 | Epsilon: 0.737
# Episode 61 | Reward: -240.8 | Epsilon: 0.733
# Episode 62 | Reward: -113.1 | Epsilon: 0.729
# Episode 63 | Reward: -115.4 | Epsilon: 0.726
# Episode 64 | Reward: -118.6 | Epsilon: 0.722
# Episode 65 | Reward: -55.4 | Epsilon: 0.718
# Episode 66 | Reward: -39.3 | Epsilon: 0.715
# Episode 67 | Reward: -62.1 | Epsilon: 0.711
# Episode 68 | Reward: -80.7 | Epsilon: 0.708
# Episode 69 | Reward: -64.5 | Epsilon: 0.704
# Episode 70 | Reward: -104.2 | Epsilon: 0.701
# Episode 71 | Reward: -99.2 | Epsilon: 0.697
# Episode 72 | Reward: -76.2 | Epsilon: 0.694
# Episode 73 | Reward: -146.6 | Epsilon: 0.690
# Episode 74 | Reward: -73.0 | Epsilon: 0.687
# Episode 75 | Reward: -95.8 | Epsilon: 0.683
# Episode 76 | Reward: -178.3 | Epsilon: 0.680
# Episode 77 | Reward: -69.7 | Epsilon: 0.676
# Episode 78 | Reward: -43.2 | Epsilon: 0.673
# Episode 79 | Reward: -158.3 | Epsilon: 0.670
# Episode 80 | Reward: -71.5 | Epsilon: 0.666
# Episode 81 | Reward: -106.4 | Epsilon: 0.663
# Episode 82 | Reward: -110.0 | Epsilon: 0.660
# Episode 83 | Reward: -41.9 | Epsilon: 0.656
# Episode 84 | Reward: -69.6 | Epsilon: 0.653
# Episode 85 | Reward: -134.1 | Epsilon: 0.650
# Episode 86 | Reward: -10.0 | Epsilon: 0.647
# Episode 87 | Reward: 1.5 | Epsilon: 0.643
# Episode 88 | Reward: -121.4 | Epsilon: 0.640
# Episode 89 | Reward: -13.5 | Epsilon: 0.637
# Episode 90 | Reward: -35.2 | Epsilon: 0.634
# Episode 91 | Reward: -133.2 | Epsilon: 0.631
# Episode 92 | Reward: -46.9 | Epsilon: 0.627
# Episode 93 | Reward: -41.1 | Epsilon: 0.624
# Episode 94 | Reward: -117.9 | Epsilon: 0.621
# Episode 95 | Reward: -56.2 | Epsilon: 0.618
# Episode 96 | Reward: -79.5 | Epsilon: 0.615
# Episode 97 | Reward: -122.9 | Epsilon: 0.612
# Episode 98 | Reward: -52.5 | Epsilon: 0.609
# Episode 99 | Reward: -28.7 | Epsilon: 0.606
# Episode 100 | Reward: -98.0 | Epsilon: 0.603
# Episode 101 | Reward: -4.6 | Epsilon: 0.600
# Episode 102 | Reward: -41.7 | Epsilon: 0.597
# Episode 103 | Reward: -116.9 | Epsilon: 0.594
# Episode 104 | Reward: -84.8 | Epsilon: 0.591
# Episode 105 | Reward: -33.0 | Epsilon: 0.588
# Episode 106 | Reward: -29.1 | Epsilon: 0.585
# Episode 107 | Reward: -52.6 | Epsilon: 0.582
# Episode 108 | Reward: -38.6 | Epsilon: 0.579
# Episode 109 | Reward: 2.9 | Epsilon: 0.576
# Episode 110 | Reward: -41.1 | Epsilon: 0.573
# Episode 111 | Reward: -46.6 | Epsilon: 0.570
# Episode 112 | Reward: -51.2 | Epsilon: 0.568
# Episode 113 | Reward: -205.0 | Epsilon: 0.565
# Episode 114 | Reward: 25.0 | Epsilon: 0.562
# Episode 115 | Reward: -195.6 | Epsilon: 0.559
# Episode 116 | Reward: -7.3 | Epsilon: 0.556
# Episode 117 | Reward: -183.7 | Epsilon: 0.554
# Episode 118 | Reward: -35.6 | Epsilon: 0.551
# Episode 119 | Reward: -14.3 | Epsilon: 0.548
# Episode 120 | Reward: -51.2 | Epsilon: 0.545
# Episode 121 | Reward: -217.8 | Epsilon: 0.543
# Episode 122 | Reward: -25.3 | Epsilon: 0.540
# Episode 123 | Reward: 42.9 | Epsilon: 0.537
# Episode 124 | Reward: -36.8 | Epsilon: 0.534
# Episode 125 | Reward: -81.6 | Epsilon: 0.532
# Episode 126 | Reward: -11.8 | Epsilon: 0.529
# Episode 127 | Reward: 10.6 | Epsilon: 0.526
# Episode 128 | Reward: -47.4 | Epsilon: 0.524
# Episode 129 | Reward: -50.2 | Epsilon: 0.521
# Episode 130 | Reward: -50.4 | Epsilon: 0.519
# Episode 131 | Reward: -29.5 | Epsilon: 0.516
# Episode 132 | Reward: -20.8 | Epsilon: 0.513
# Episode 133 | Reward: -121.2 | Epsilon: 0.511
# Episode 134 | Reward: 23.5 | Epsilon: 0.508
# Episode 135 | Reward: -19.8 | Epsilon: 0.506
# Episode 136 | Reward: -12.8 | Epsilon: 0.503
# Episode 137 | Reward: -114.8 | Epsilon: 0.501
# Episode 138 | Reward: -59.2 | Epsilon: 0.498
# Episode 139 | Reward: -79.2 | Epsilon: 0.496
# Episode 140 | Reward: -52.9 | Epsilon: 0.493
# Episode 141 | Reward: -20.3 | Epsilon: 0.491
# Episode 142 | Reward: -307.4 | Epsilon: 0.488
# Episode 143 | Reward: -65.7 | Epsilon: 0.486
# Episode 144 | Reward: -55.8 | Epsilon: 0.483
# Episode 145 | Reward: -37.0 | Epsilon: 0.481
# Episode 146 | Reward: -209.9 | Epsilon: 0.479
# Episode 147 | Reward: -28.8 | Epsilon: 0.476
# Episode 148 | Reward: -68.2 | Epsilon: 0.474
# Episode 149 | Reward: -31.2 | Epsilon: 0.471
# Episode 150 | Reward: -250.9 | Epsilon: 0.469
# Episode 151 | Reward: -28.3 | Epsilon: 0.467
# Episode 152 | Reward: -34.3 | Epsilon: 0.464
# Episode 153 | Reward: -69.8 | Epsilon: 0.462
# Episode 154 | Reward: 50.3 | Epsilon: 0.460
# Episode 155 | Reward: 11.3 | Epsilon: 0.458
# Episode 156 | Reward: -91.2 | Epsilon: 0.455
# Episode 157 | Reward: -1.1 | Epsilon: 0.453
# Episode 158 | Reward: -53.6 | Epsilon: 0.451
# Episode 159 | Reward: -63.6 | Epsilon: 0.448
# Episode 160 | Reward: -117.6 | Epsilon: 0.446
# Episode 161 | Reward: 27.1 | Epsilon: 0.444
# Episode 162 | Reward: 39.8 | Epsilon: 0.442
# Episode 163 | Reward: -0.3 | Epsilon: 0.440
# Episode 164 | Reward: 9.8 | Epsilon: 0.437
# Episode 165 | Reward: -28.2 | Epsilon: 0.435
# Episode 166 | Reward: 2.4 | Epsilon: 0.433
# Episode 167 | Reward: -37.9 | Epsilon: 0.431
# Episode 168 | Reward: -83.5 | Epsilon: 0.429
# Episode 169 | Reward: -40.4 | Epsilon: 0.427
# Episode 170 | Reward: -25.7 | Epsilon: 0.424
# Episode 171 | Reward: -12.1 | Epsilon: 0.422
# Episode 172 | Reward: -82.3 | Epsilon: 0.420
# Episode 173 | Reward: -25.2 | Epsilon: 0.418
# Episode 174 | Reward: -38.0 | Epsilon: 0.416
# Episode 175 | Reward: -17.8 | Epsilon: 0.414
# Episode 176 | Reward: -116.1 | Epsilon: 0.412
# Episode 177 | Reward: -45.7 | Epsilon: 0.410
# Episode 178 | Reward: -3.6 | Epsilon: 0.408
# Episode 179 | Reward: -84.1 | Epsilon: 0.406
# Episode 180 | Reward: -13.2 | Epsilon: 0.404
# Episode 181 | Reward: 0.6 | Epsilon: 0.402
# Episode 182 | Reward: -23.3 | Epsilon: 0.400
# Episode 183 | Reward: -26.3 | Epsilon: 0.398
# Episode 184 | Reward: 14.2 | Epsilon: 0.396
# Episode 185 | Reward: -59.4 | Epsilon: 0.394
# Episode 186 | Reward: -30.0 | Epsilon: 0.392
# Episode 187 | Reward: -360.2 | Epsilon: 0.390
# Episode 188 | Reward: -29.5 | Epsilon: 0.388
# Episode 189 | Reward: -20.1 | Epsilon: 0.386
# Episode 190 | Reward: -364.0 | Epsilon: 0.384
# Episode 191 | Reward: -79.7 | Epsilon: 0.382
# Episode 192 | Reward: -17.3 | Epsilon: 0.380
# Episode 193 | Reward: -24.3 | Epsilon: 0.378
# Episode 194 | Reward: 25.5 | Epsilon: 0.376
# Episode 195 | Reward: -69.7 | Epsilon: 0.374
# Episode 196 | Reward: -4.4 | Epsilon: 0.373
# Episode 197 | Reward: -15.6 | Epsilon: 0.371
# Episode 198 | Reward: -309.8 | Epsilon: 0.369
# Episode 199 | Reward: 27.1 | Epsilon: 0.367
# Episode 200 | Reward: 1.0 | Epsilon: 0.365
# Episode 201 | Reward: -127.4 | Epsilon: 0.363
# Episode 202 | Reward: -22.6 | Epsilon: 0.361
# Episode 203 | Reward: -25.7 | Epsilon: 0.360
# Episode 204 | Reward: 0.8 | Epsilon: 0.358
# Episode 205 | Reward: -152.6 | Epsilon: 0.356
# Episode 206 | Reward: -93.0 | Epsilon: 0.354
# Episode 207 | Reward: -3.6 | Epsilon: 0.353
# Episode 208 | Reward: -285.3 | Epsilon: 0.351
# Episode 209 | Reward: -52.9 | Epsilon: 0.349
# Episode 210 | Reward: 5.5 | Epsilon: 0.347
# Episode 211 | Reward: -158.9 | Epsilon: 0.346
# Episode 212 | Reward: -31.2 | Epsilon: 0.344
# Episode 213 | Reward: -95.6 | Epsilon: 0.342
# Episode 214 | Reward: -265.7 | Epsilon: 0.340
# Episode 215 | Reward: -29.3 | Epsilon: 0.339
# Episode 216 | Reward: -36.4 | Epsilon: 0.337
# Episode 217 | Reward: 45.1 | Epsilon: 0.335
# Episode 218 | Reward: -23.4 | Epsilon: 0.334
# Episode 219 | Reward: -296.4 | Epsilon: 0.332
# Episode 220 | Reward: 86.0 | Epsilon: 0.330
# Episode 221 | Reward: 3.4 | Epsilon: 0.329
# Episode 222 | Reward: -48.0 | Epsilon: 0.327
# Episode 223 | Reward: -241.1 | Epsilon: 0.325
# Episode 224 | Reward: -326.5 | Epsilon: 0.324
# Episode 225 | Reward: 16.4 | Epsilon: 0.322
# Episode 226 | Reward: -58.7 | Epsilon: 0.321
# Episode 227 | Reward: -156.0 | Epsilon: 0.319
# Episode 228 | Reward: -56.0 | Epsilon: 0.317
# Episode 229 | Reward: 91.9 | Epsilon: 0.316
# Episode 230 | Reward: -55.3 | Epsilon: 0.314
# Episode 231 | Reward: 14.3 | Epsilon: 0.313
# Episode 232 | Reward: -154.2 | Epsilon: 0.311
# Episode 233 | Reward: 196.1 | Epsilon: 0.309
# Episode 234 | Reward: 53.6 | Epsilon: 0.308
# Episode 235 | Reward: -22.9 | Epsilon: 0.306
# Episode 236 | Reward: -50.5 | Epsilon: 0.305
# Episode 237 | Reward: -188.8 | Epsilon: 0.303
# Episode 238 | Reward: -49.9 | Epsilon: 0.302
# Episode 239 | Reward: 4.4 | Epsilon: 0.300
# Episode 240 | Reward: 92.6 | Epsilon: 0.299
# Episode 241 | Reward: 127.9 | Epsilon: 0.297
# Episode 242 | Reward: -234.8 | Epsilon: 0.296
# Episode 243 | Reward: -38.0 | Epsilon: 0.294
# Episode 244 | Reward: -61.2 | Epsilon: 0.293
# Episode 245 | Reward: -48.3 | Epsilon: 0.291
# Episode 246 | Reward: -90.9 | Epsilon: 0.290
# Episode 247 | Reward: 92.9 | Epsilon: 0.288
# Episode 248 | Reward: -15.5 | Epsilon: 0.287
# Episode 249 | Reward: 115.5 | Epsilon: 0.286
# Episode 250 | Reward: -211.0 | Epsilon: 0.284
# Episode 251 | Reward: -41.3 | Epsilon: 0.283
# Episode 252 | Reward: -7.9 | Epsilon: 0.281
# Episode 253 | Reward: 202.1 | Epsilon: 0.280
# Episode 254 | Reward: 26.6 | Epsilon: 0.279
# Episode 255 | Reward: -30.3 | Epsilon: 0.277
# Episode 256 | Reward: -44.2 | Epsilon: 0.276
# Episode 257 | Reward: -23.1 | Epsilon: 0.274
# Episode 258 | Reward: -80.6 | Epsilon: 0.273
# Episode 259 | Reward: -28.4 | Epsilon: 0.272
# Episode 260 | Reward: -93.7 | Epsilon: 0.270
# Episode 261 | Reward: -54.6 | Epsilon: 0.269
# Episode 262 | Reward: 99.5 | Epsilon: 0.268
# Episode 263 | Reward: 6.3 | Epsilon: 0.266
# Episode 264 | Reward: 116.9 | Epsilon: 0.265
# Episode 265 | Reward: -80.0 | Epsilon: 0.264
# Episode 266 | Reward: 140.2 | Epsilon: 0.262
# Episode 267 | Reward: 114.9 | Epsilon: 0.261
# Episode 268 | Reward: 110.3 | Epsilon: 0.260
# Episode 269 | Reward: -57.8 | Epsilon: 0.258
# Episode 270 | Reward: -238.7 | Epsilon: 0.257
# Episode 271 | Reward: -73.8 | Epsilon: 0.256
# Episode 272 | Reward: -97.3 | Epsilon: 0.255
# Episode 273 | Reward: -48.4 | Epsilon: 0.253
# Episode 274 | Reward: -59.1 | Epsilon: 0.252
# Episode 275 | Reward: -9.4 | Epsilon: 0.251
# Episode 276 | Reward: 89.7 | Epsilon: 0.249
# Episode 277 | Reward: -26.7 | Epsilon: 0.248
# Episode 278 | Reward: 130.0 | Epsilon: 0.247
# Episode 279 | Reward: -67.2 | Epsilon: 0.246
# Episode 280 | Reward: 106.7 | Epsilon: 0.245
# Episode 281 | Reward: -165.9 | Epsilon: 0.243
# Episode 282 | Reward: -67.9 | Epsilon: 0.242
# Episode 283 | Reward: -52.1 | Epsilon: 0.241
# Episode 284 | Reward: 124.7 | Epsilon: 0.240
# Episode 285 | Reward: -52.7 | Epsilon: 0.238
# Episode 286 | Reward: -219.4 | Epsilon: 0.237
# Episode 287 | Reward: -23.3 | Epsilon: 0.236
# Episode 288 | Reward: -11.1 | Epsilon: 0.235
# Episode 289 | Reward: -8.2 | Epsilon: 0.234
# Episode 290 | Reward: -82.4 | Epsilon: 0.233
# Episode 291 | Reward: -323.0 | Epsilon: 0.231
# Episode 292 | Reward: -7.3 | Epsilon: 0.230
# Episode 293 | Reward: -55.1 | Epsilon: 0.229
# Episode 294 | Reward: 0.2 | Epsilon: 0.228
# Episode 295 | Reward: -168.3 | Epsilon: 0.227
# Episode 296 | Reward: -81.9 | Epsilon: 0.226
# Episode 297 | Reward: -84.2 | Epsilon: 0.225
# Episode 298 | Reward: -45.1 | Epsilon: 0.223
# Episode 299 | Reward: -21.2 | Epsilon: 0.222
# Episode 300 | Reward: -30.4 | Epsilon: 0.221
# Episode 301 | Reward: -337.1 | Epsilon: 0.220
# Episode 302 | Reward: 262.2 | Epsilon: 0.219
# Episode 303 | Reward: -57.9 | Epsilon: 0.218
# Episode 304 | Reward: 10.4 | Epsilon: 0.217
# Episode 305 | Reward: -188.0 | Epsilon: 0.216
# Episode 306 | Reward: -87.6 | Epsilon: 0.215
# Episode 307 | Reward: -88.7 | Epsilon: 0.214
# Episode 308 | Reward: -78.0 | Epsilon: 0.212
# Episode 309 | Reward: -31.7 | Epsilon: 0.211
# Episode 310 | Reward: -65.0 | Epsilon: 0.210
# Episode 311 | Reward: -70.8 | Epsilon: 0.209
# Episode 312 | Reward: -235.3 | Epsilon: 0.208
# Episode 313 | Reward: -18.6 | Epsilon: 0.207
# Episode 314 | Reward: -71.6 | Epsilon: 0.206
# Episode 315 | Reward: -7.5 | Epsilon: 0.205
# Episode 316 | Reward: -336.3 | Epsilon: 0.204
# Episode 317 | Reward: 98.7 | Epsilon: 0.203
# Episode 318 | Reward: 18.8 | Epsilon: 0.202
# Episode 319 | Reward: -146.0 | Epsilon: 0.201
# Episode 320 | Reward: -127.2 | Epsilon: 0.200
# Episode 321 | Reward: -43.9 | Epsilon: 0.199
# Episode 322 | Reward: -40.6 | Epsilon: 0.198
# Episode 323 | Reward: -47.7 | Epsilon: 0.197
# Episode 324 | Reward: -2.2 | Epsilon: 0.196
# Episode 325 | Reward: 10.0 | Epsilon: 0.195
# Episode 326 | Reward: -44.3 | Epsilon: 0.194
# Episode 327 | Reward: -53.1 | Epsilon: 0.193
# Episode 328 | Reward: -67.1 | Epsilon: 0.192
# Episode 329 | Reward: 0.0 | Epsilon: 0.191
# Episode 330 | Reward: 137.6 | Epsilon: 0.190
# Episode 331 | Reward: -5.6 | Epsilon: 0.189
# Episode 332 | Reward: -124.9 | Epsilon: 0.188
# Episode 333 | Reward: -50.1 | Epsilon: 0.187
# Episode 334 | Reward: -370.9 | Epsilon: 0.187
# Episode 335 | Reward: -43.4 | Epsilon: 0.186
# Episode 336 | Reward: -25.0 | Epsilon: 0.185
# Episode 337 | Reward: -20.3 | Epsilon: 0.184
# Episode 338 | Reward: -39.9 | Epsilon: 0.183
# Episode 339 | Reward: -15.7 | Epsilon: 0.182
# Episode 340 | Reward: -71.4 | Epsilon: 0.181
# Episode 341 | Reward: -100.6 | Epsilon: 0.180
# Episode 342 | Reward: -58.5 | Epsilon: 0.179
# Episode 343 | Reward: -153.7 | Epsilon: 0.178
# Episode 344 | Reward: -104.8 | Epsilon: 0.177
# Episode 345 | Reward: 37.1 | Epsilon: 0.177
# Episode 346 | Reward: 2.3 | Epsilon: 0.176
# Episode 347 | Reward: -74.2 | Epsilon: 0.175
# Episode 348 | Reward: -7.6 | Epsilon: 0.174
# Episode 349 | Reward: 5.3 | Epsilon: 0.173
# Episode 350 | Reward: 82.5 | Epsilon: 0.172
# Episode 351 | Reward: -95.0 | Epsilon: 0.171
# Episode 352 | Reward: -33.4 | Epsilon: 0.170
# Episode 353 | Reward: -7.1 | Epsilon: 0.170
# Episode 354 | Reward: -42.3 | Epsilon: 0.169
# Episode 355 | Reward: -110.3 | Epsilon: 0.168
# Episode 356 | Reward: -17.8 | Epsilon: 0.167
# Episode 357 | Reward: -297.6 | Epsilon: 0.166
# Episode 358 | Reward: -44.6 | Epsilon: 0.165
# Episode 359 | Reward: -89.9 | Epsilon: 0.165
# Episode 360 | Reward: -9.2 | Epsilon: 0.164
# Episode 361 | Reward: -20.2 | Epsilon: 0.163
# Episode 362 | Reward: -136.0 | Epsilon: 0.162
# Episode 363 | Reward: -169.2 | Epsilon: 0.161
# Episode 364 | Reward: 1.7 | Epsilon: 0.160
# Episode 365 | Reward: -68.8 | Epsilon: 0.160
# Episode 366 | Reward: -69.0 | Epsilon: 0.159
# Episode 367 | Reward: -19.0 | Epsilon: 0.158
# Episode 368 | Reward: 42.3 | Epsilon: 0.157
# Episode 369 | Reward: 231.6 | Epsilon: 0.157
# Episode 370 | Reward: 54.2 | Epsilon: 0.156
# Episode 371 | Reward: -175.8 | Epsilon: 0.155
# Episode 372 | Reward: 234.1 | Epsilon: 0.154
# Episode 373 | Reward: -252.0 | Epsilon: 0.153
# Episode 374 | Reward: -105.8 | Epsilon: 0.153
# Episode 375 | Reward: -11.3 | Epsilon: 0.152
# Episode 376 | Reward: -152.8 | Epsilon: 0.151
# Episode 377 | Reward: -161.9 | Epsilon: 0.150
# Episode 378 | Reward: -10.0 | Epsilon: 0.150
# Episode 379 | Reward: -170.2 | Epsilon: 0.149
# Episode 380 | Reward: -113.1 | Epsilon: 0.148
# Episode 381 | Reward: -36.1 | Epsilon: 0.147
# Episode 382 | Reward: -11.3 | Epsilon: 0.147
# Episode 383 | Reward: -208.3 | Epsilon: 0.146
# Episode 384 | Reward: -165.7 | Epsilon: 0.145
# Episode 385 | Reward: -194.2 | Epsilon: 0.144
# Episode 386 | Reward: -45.6 | Epsilon: 0.144
# Episode 387 | Reward: -262.0 | Epsilon: 0.143
# Episode 388 | Reward: -241.7 | Epsilon: 0.142
# Episode 389 | Reward: -277.0 | Epsilon: 0.142
# Episode 390 | Reward: -45.5 | Epsilon: 0.141
# Episode 391 | Reward: -165.1 | Epsilon: 0.140
# Episode 392 | Reward: -139.6 | Epsilon: 0.139
# Episode 393 | Reward: 17.3 | Epsilon: 0.139
# Episode 394 | Reward: -106.8 | Epsilon: 0.138
# Episode 395 | Reward: -35.2 | Epsilon: 0.137
# Episode 396 | Reward: -87.5 | Epsilon: 0.137
# Episode 397 | Reward: 59.4 | Epsilon: 0.136
# Episode 398 | Reward: -14.2 | Epsilon: 0.135
# Episode 399 | Reward: -187.7 | Epsilon: 0.135
# Episode 400 | Reward: 37.0 | Epsilon: 0.134
# Episode 401 | Reward: -198.4 | Epsilon: 0.133
# Episode 402 | Reward: -118.0 | Epsilon: 0.133
# Episode 403 | Reward: -129.5 | Epsilon: 0.132
# Episode 404 | Reward: -93.8 | Epsilon: 0.131
# Episode 405 | Reward: -160.4 | Epsilon: 0.131
# Episode 406 | Reward: -307.4 | Epsilon: 0.130
# Episode 407 | Reward: 38.0 | Epsilon: 0.129
# Episode 408 | Reward: -145.7 | Epsilon: 0.129
# Episode 409 | Reward: 38.0 | Epsilon: 0.128
# Episode 410 | Reward: -109.5 | Epsilon: 0.127
# Episode 411 | Reward: -264.3 | Epsilon: 0.127
# Episode 412 | Reward: -48.3 | Epsilon: 0.126
# Episode 413 | Reward: 61.1 | Epsilon: 0.126
# Episode 414 | Reward: -188.1 | Epsilon: 0.125
# Episode 415 | Reward: -180.5 | Epsilon: 0.124
# Episode 416 | Reward: -163.5 | Epsilon: 0.124
# Episode 417 | Reward: -74.1 | Epsilon: 0.123
# Episode 418 | Reward: 27.6 | Epsilon: 0.122
# Episode 419 | Reward: -76.9 | Epsilon: 0.122

# %%
# ---- Визуализация ----
plt.plot(rewards)
plt.title("DQN Training Reward")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid()
plt.show()

# %%
import imageio
from IPython.display import HTML
from base64 import b64encode

# %%
torch.save(qnet.state_dict(), "dqn_enhansed_lunarlander.pt")

# %%
def play_colab(model, episodes=1):
  env = gym.make("LunarLander-v3", render_mode="rgb_array")
  frames = []

  for ep in range(episodes):
    state, _ = env.reset()
    done = False

    while not done:
      st = torch.tensor(state, dtype=torch.float32).unsqueeze(0).to(device)
      action = torch.argmax(model(st)).item()

      state, _, term, trunc, _ = env.step(action)
      done = term or trunc

      frame = env.render()
      frames.append(frame)

  env.close()

  # save video
  imageio.mimsave("lander.mp4", frames, fps=60)

  mp4 = open("lander.mp4",'rb').read()
  data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
  return HTML(f"<video width=480 controls><source src='{data_url}' type='video/mp4'></video>")

# %%
obs_dim = 8         # у LunarLander-v3 всегда 8
act_dim = 4         # 4 действия

model = DQN(obs_dim, act_dim).to(device)
model.load_state_dict(torch.load("dqn_lunarlander.pt", map_location=device))
model.eval()

play_colab(model)
